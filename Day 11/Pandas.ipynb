# %% [markdown]
# # Machine Learning Steps

# %% [markdown]
# #### 1.Gather Data
# #### 2.Process Data
# #### 3.Choose Model
# #### 4.Train Model
# #### 5.Test the Model
# #### 6.Hypertuning
# #### 7.Test against real world data

# %%
pip install pandas

# %%
import pandas as pd
import numpy as np

# %%
series=pd.Series([1,2,3,4,5])
print(series)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
series=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
print(series)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
series=pd.Series(np.random.randn(5),index=['a','b','c','d','e'])   #randn gives negatives values also and rand gives postitve 
print(series)
# Out:
# a   -0.296514
# b    1.121193
# c    0.537936
# d    1.257922
# e   -0.312329
# dtype: float64

# %% [markdown]
# ## Creating Series using dictionray

# %%
d={'a':1,'b':2,'c':3}
d1=pd.Series(d)
d1
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
#[] Series
#[[]] dataframe

# %%
#d1[[1,2]]
d1.iloc[[1,2]] #index based locatiion 
#the first version gives warning
# Out:
# b    2
# c    3
# dtype: int64

# %%
series1=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
series2=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
series1+series2
#this opertaion will perform only if indices of series are same otherwise  it gives Nan
# Out:
# a     2
# b     4
# c     6
# d     8
# e    10
# dtype: int64

# %% [markdown]
# ## Dataframe

# %%
df=pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df=pd.DataFrame(columns=['c1','c2','c3'])
print(df)
# Out:
# Empty DataFrame
# Columns: [c1, c2, c3]
# Index: []

# %%
df=pd.DataFrame(columns=['c1','c2','c3','c4'],index=range(1,6))  #index is for creating no of rows
print(df)
# Out:
#     c1   c2   c3   c4
# 1  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN
# 5  NaN  NaN  NaN  NaN

# %%
dictionary={'a':1,'b':2,'c':3}
df1=pd.DataFrame([dictionary])
df1
# Out:
#    a  b  c
# 0  1  2  3

# %%
print(df.columns)
print(df1.columns)
# Out:
# Index(['c1', 'c2', 'c3', 'c4'], dtype='object')
# Index(['a', 'b', 'c'], dtype='object')

# %%
myList=[['Apple','Red'],['Banana','Yellow'],['Orange','orange']]
myData=pd.DataFrame(myList,index=range(1,4))
myData
# Out:
#         0       1
# 1   Apple     Red
# 2  Banana  Yellow
# 3  Orange  orange

# %%
myList=[['Apple','Red'],['Banana','Yellow'],['Orange','orange']]
myData=pd.DataFrame(myList,columns=['Fruits','Color'],index=range(1,4))
myData
# Out:
#    Fruits   Color
# 1   Apple     Red
# 2  Banana  Yellow
# 3  Orange  orange

# %%
myList1=np.array([[0,1],[2,3],[4,5]])
myData1=pd.DataFrame(myList1,columns=['Even','Odd'],index=range(1,4))
myData1
# Out:
#    Even  Odd
# 1     0    1
# 2     2    3
# 3     4    5

# %% [markdown]
# ## Load csv Data using pandas

# %%
df=pd.read_csv('./csv_files/cereals.csv')
df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df.set_index('name') #it returns new dataframe
# Out:
#                            calories  protein  vitamins     rating
# name
# 100% Bran                        70        4        25  68.402973
# 100% Natural Bran               120        3         0  33.983679
# All-Bran                         70        4        25  59.425505
# All-Bran with Extra Fiber        50        4        25  93.704912
# Almond Delight                  110        2        25  34.384843
# Apple Cinnamon Cheerios         110        2        25  29.509541
# Apple Jacks                     110        2        25  33.174094
# Basic 4                         130        3        25  37.038562
# Bran Chex                        90        2        25  49.120253
# Bran Flakes                      90        3        25  53.313813

# %%
#df.set_index('name',inplace=True)
df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df.head(2)  #top rows default is 5
# Out:
#                 name  calories  protein  vitamins     rating
# 0          100% Bran        70        4        25  68.402973
# 1  100% Natural Bran       120        3         0  33.983679

# %%
df.tail()
# Out:
#                       name  calories  protein  vitamins     rating
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 7                  Basic 4       130        3        25  37.038562
# 8                Bran Chex        90        2        25  49.120253
# 9              Bran Flakes        90        3        25  53.313813

# %%
df.describe()
# Out:
#          calories    protein   vitamins     rating
# count   10.000000  10.000000  10.000000  10.000000
# mean    95.000000   2.900000  22.500000  49.205817
# std     25.495098   0.875595   7.905694  20.315297
# min     50.000000   2.000000   0.000000  29.509541
# 25%     75.000000   2.000000  25.000000  34.083970
# 50%    100.000000   3.000000  25.000000  43.079408
# 75%    110.000000   3.750000  25.000000  57.897582
# max    130.000000   4.000000  25.000000  93.704912

# %% [markdown]
# # Slicing rows using bracket operators

# %%
df[1:4]
# Out:
#                         name  calories  protein  vitamins     rating
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912

# %%
#df['calories':'rating']

# %%
df[['calories','rating']] #single dimension we cant give multiple throws error
# Out:
#    calories     rating
# 0        70  68.402973
# 1       120  33.983679
# 2        70  59.425505
# 3        50  93.704912
# 4       110  34.384843
# 5       110  29.509541
# 6       110  33.174094
# 7       130  37.038562
# 8        90  49.120253
# 9        90  53.313813

# %% [markdown]
# ## Boolean filter

# %%
df1=df[0:5]
boolean_list=[True,False,True,True,False]
df1[boolean_list]
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912

# %%
condition=df['calories']>70
df[condition] 

#df[['calories']>70]  #gives error
# Out:
#                       name  calories  protein  vitamins     rating
# 1        100% Natural Bran       120        3         0  33.983679
# 4           Almond Delight       110        2        25  34.384843
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 7                  Basic 4       130        3        25  37.038562
# 8                Bran Chex        90        2        25  49.120253
# 9              Bran Flakes        90        3        25  53.313813

# %% [markdown]
# ## filters using &(and)  and |(or) opertor

# %%
df[(df['calories']>70)&(df['protein']<3)]
# Out:
#                       name  calories  protein  vitamins     rating
# 4           Almond Delight       110        2        25  34.384843
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 8                Bran Chex        90        2        25  49.120253

# %%
df[(df['calories']>70)|(df['protein']<3)]
# Out:
#                       name  calories  protein  vitamins     rating
# 1        100% Natural Bran       120        3         0  33.983679
# 4           Almond Delight       110        2        25  34.384843
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 7                  Basic 4       130        3        25  37.038562
# 8                Bran Chex        90        2        25  49.120253
# 9              Bran Flakes        90        3        25  53.313813

# %% [markdown]
# # filtering using loc

# %%
df.loc[2,'protein'] # returns in series format
# Out:
# np.int64(4)

# %%
df.loc[0:4,['protein','name']]
# Out:
#    protein                       name
# 0        4                  100% Bran
# 1        3          100% Natural Bran
# 2        4                   All-Bran
# 3        4  All-Bran with Extra Fiber
# 4        2             Almond Delight

# %%
df.iloc[1,2]
# Out:
# np.int64(3)

# %%
df.iloc[[1,2]]
# Out:
#                 name  calories  protein  vitamins     rating
# 1  100% Natural Bran       120        3         0  33.983679
# 2           All-Bran        70        4        25  59.425505

# %%
df.loc[[2],['protein']]
# Out:
#    protein
# 2        4

# %%
df.loc[2:4,['protein']]
# Out:
#    protein
# 2        4
# 3        4
# 4        2

# %%
# more than one column will automatically considered as dataframe so no need to specify in[]
df.loc[0:4,'name':'protein']
# Out:
#                         name  calories  protein
# 0                  100% Bran        70        4
# 1          100% Natural Bran       120        3
# 2                   All-Bran        70        4
# 3  All-Bran with Extra Fiber        50        4
# 4             Almond Delight       110        2

# %%
df.iloc[0:5,0:3]   #first represent row ,second represnt column
# Out:
#                         name  calories  protein
# 0                  100% Bran        70        4
# 1          100% Natural Bran       120        3
# 2                   All-Bran        70        4
# 3  All-Bran with Extra Fiber        50        4
# 4             Almond Delight       110        2

# %%
df.iloc[[0,2,4],0:3]
# Out:
#              name  calories  protein
# 0       100% Bran        70        4
# 2        All-Bran        70        4
# 4  Almond Delight       110        2

# %% [markdown]
# # Addig rows and columns in dataframe

# %%
#it will update original dataframe
df1.loc[4]=['ankita',110,1,25,23.22]
df1
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4                     ankita       110        1        25  23.220000

# %%
df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4                     ankita       110        1        25  23.220000
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df1['new_col']=["avc",28,2,33,22.3]
df1
# Out:
#                         name  calories  protein  vitamins     rating new_col
# 0                  100% Bran        70        4        25  68.402973     avc
# 1          100% Natural Bran       120        3         0  33.983679      28
# 2                   All-Bran        70        4        25  59.425505       2
# 3  All-Bran with Extra Fiber        50        4        25  93.704912      33
# 4                     ankita       110        1        25  23.220000    22.3

# %% [markdown]
# #### using .copy() it do deep copy (changes made in df will not affect in df1)
# #### using df1=df[0:5] it do shallow copy (changes made in df will affect in df1)

# %%
df1=df.iloc[0:5].copy()
df1
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4                     ankita       110        1        25  23.220000

# %%
#df1.drop(4,axis=0,inplace=True)  #axis=0 row wise
df1
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4                     ankita       110        1        25  23.220000

# %%
df1
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4                     ankita       110        1        25  23.220000

# %%
#df1.drop('vitamins',axis=1)  #drops vitamins column and return new df

# %%
df1  #doesnt affect to original data
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4                     ankita       110        1        25  23.220000

# %% [markdown]
# ## sorting values

# %%
ascending_df=df.sort_values(by='protein')
ascending_df
# Out:
#                         name  calories  protein  vitamins     rating
# 4                     ankita       110        1        25  23.220000
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 8                  Bran Chex        90        2        25  49.120253
# 7                    Basic 4       130        3        25  37.038562
# 1          100% Natural Bran       120        3         0  33.983679
# 9                Bran Flakes        90        3        25  53.313813
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 2                   All-Bran        70        4        25  59.425505
# 0                  100% Bran        70        4        25  68.402973

# %%
descending_df=df.sort_values(by='calories',ascending=False)
descending_df
# Out:
#                         name  calories  protein  vitamins     rating
# 7                    Basic 4       130        3        25  37.038562
# 1          100% Natural Bran       120        3         0  33.983679
# 6                Apple Jacks       110        2        25  33.174094
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 4                     ankita       110        1        25  23.220000
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813
# 0                  100% Bran        70        4        25  68.402973
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912

# %% [markdown]
# ## chaning column index

# %%
#df.columns=['col1','col2','col3','col4','col5']
df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4                     ankita       110        1        25  23.220000
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %% [markdown]
# ## export data to another csv file

# %%
#if we do not give index_label=False then it takes index column from df and assume it as a new column and add index 
#df.to_csv('./csv_files/myfiles.csv')

# %%
df.to_csv('./csv_files/myfiles.csv',index_label=False)

# %%
newdf=pd.read_csv('./csv_files/myfiles.csv')
newdf
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4                     ankita       110        1        25  23.220000
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df2=df[5:8].copy() #deep copy
df2
# Out:
#                       name  calories  protein  vitamins     rating
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 7                  Basic 4       130        3        25  37.038562

# %%
df2=df2.reset_index(drop=True)    #reset the indexes from 0
df2
# Out:
#                       name  calories  protein  vitamins     rating
# 0  Apple Cinnamon Cheerios       110        2        25  29.509541
# 1              Apple Jacks       110        2        25  33.174094
# 2                  Basic 4       130        3        25  37.038562

# %%
df1=df1.drop('new_col',axis=1)
df1
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4                     ankita       110        1        25  23.220000

# %%
df=pd.read_csv('./csv_files/cereals.csv')
df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
pd.concat([df,df1])  #indexes gets repeated( takes indexed from df sepratedly)
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# ...

# %%
pd.concat([df,df1],ignore_index=True) #index are continous
# Out:
#                          name  calories  protein  vitamins     rating
# 0                   100% Bran        70        4        25  68.402973
# 1           100% Natural Bran       120        3         0  33.983679
# 2                    All-Bran        70        4        25  59.425505
# 3   All-Bran with Extra Fiber        50        4        25  93.704912
# 4              Almond Delight       110        2        25  34.384843
# 5     Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                 Apple Jacks       110        2        25  33.174094
# 7                     Basic 4       130        3        25  37.038562
# 8                   Bran Chex        90        2        25  49.120253
# 9                 Bran Flakes        90        3        25  53.313813
# 10                  100% Bran        70        4        25  68.402973
# 11          100% Natural Bran       120        3         0  33.983679
# ...

# %%
data={'Gender':['male','female'],'Score':[50,80]}
# newdf=pd.DataFrame.from_dict(data)
newdf=pd.DataFrame(data)
newdf
# Out:
#    Gender  Score
# 0    male     50
# 1  female     80

# %%
group=newdf.groupby(newdf['Gender']).mean()
group
# Out:
#         Score
# Gender
# female   80.0
# male     50.0

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from numpy import NaN
#
# ImportError: cannot import name 'NaN' from 'numpy' (C:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\__init__.py)
